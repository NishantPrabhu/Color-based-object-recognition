# %% [markdown]
# # Flann Index Matching
# We'll used SIFT, VGG and BRISK features.

# %%
import cv2
import os
import numpy as np
from glob import glob
from tqdm.notebook import tqdm
import matplotlib.pyplot as plt
from IPython.display import clear_output

# %%
# Image paths
test_path = '../../data/test_images/test_image_1.jpeg'
path_1 = '../../data/Biscuits/400018.jpg'
path_2 = '../../data/DentalCare/100004.jpg'

test_img = cv2.imread(test_path, 0)
img_1 = cv2.imread(path_1, 0)
img_2 = cv2.imread(path_2, 0)

# %%
# SIFT features
sift = cv2.xfeatures2d.SIFT_create()
kp1, desc_1 = sift.detectAndCompute(img_1, None)
kp2, desc_2 = sift.detectAndCompute(img_2, None)
kp_test, desc_test = sift.detectAndCompute(test_img, None)

# %%
# Flann matcher
FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)

flann = cv2.FlannBasedMatcher(index_params, search_params)
matches_1 = flann.knnMatch(desc_1, desc_test, k=2)
matches_2 = flann.knnMatch(desc_2, desc_test, k=2)

# %%
good_1 = []
for m, n in matches_1:
    if m.distance < 0.7*n.distance:
        good_1.append(m)
        
good_2 = []
for m, n in matches_2:
    if m.distance < 0.7*n.distance:
        good_2.append(m)

# %% [markdown]
# ## Trying for all images
# Works fine for the two we chose. Let's see if it does fine overall.

# %%
# Sift features
sift = cv2.xfeatures2d.SIFT_create()

# Flann based matcher
FLANN_INDEX_KDTREE = 0
index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
search_params = dict(checks=50)
flann = cv2.FlannBasedMatcher(index_params, search_params)

# %%
# Load test image
test_path = '../../data/test_images/test_image_1.jpeg'
test_img = cv2.imread(test_path, 0)

_, desc_test = sift.detectAndCompute(test_img, None)

# %%
# Run over every image and find matches
file_match_dict = {}

for folder in os.listdir('../../data'):
    for path in tqdm(glob('../../data/'+folder+'/*.jpg')):
        img = cv2.imread(path, 0)
        _, desc = sift.detectAndCompute(img, None)
        # Matching
        matches = flann.knnMatch(desc, desc_test, k=2)
        # Good matches a/o Lowe's ratio test
        good = 0
        for m, n in matches:
            if m.distance < 0.7*n.distance:
                good += 1
        # Update dict
        file_match_dict.update({path: good})
        
# Find image with maximum matches
paths = list(file_match_dict.keys())
win_path = sorted(paths, key=lambda x: file_match_dict[x])[-1]
win_img = cv2.imread(win_path, 0)

clear_output()
# Show input and chosen image
fig = plt.figure()
fig.add_subplot(121)
plt.imshow(test_img, cmap='gray')
fig.add_subplot(122)
plt.imshow(win_img, cmap='gray')
plt.tight_layout()
plt.show()
# Out:
# HBox(children=(IntProgress(value=0, max=189), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-22a9a67148d2> in <module>
#       7         _, desc = sift.detectAndCompute(img, None)
#       8         # Matching
# ----> 9         matches = flann.knnMatch(desc, desc_test, k=2)
#      10         # Good matches a/o Lowe's ratio test
#      11         good = 0
#
# KeyboardInterrupt:

# %%
sorted(list(file_match_dict.keys()), key=lambda x: file_match_dict[x], reverse=True)
# Out:
# ['../../data/Snacks/700221.jpg',
#  '../../data/Biscuits/400018.jpg',
#  '../../data/Soaps/200093.jpg',
#  '../../data/Beverages/600358.jpg',
#  '../../data/Snacks/700167.jpg',
#  '../../data/Beverages/600155.jpg',
#  '../../data/Biscuits/400029.jpg',
#  '../../data/Snacks/700217.jpg',
#  '../../data/Beverages/600004.jpg',
#  '../../data/Snacks/700372.jpg',
#  '../../data/Snacks/700192.jpg',
#  '../../data/Soaps/200412.jpg',
#  '../../data/Soaps/200232.jpg',
#  '../../data/Snacks/700367.jpg',
#  '../../data/Biscuits/400295.jpg',
#  '../../data/DentalCare/200464.jpg',
#  '../../data/Beverages/600334.jpg',
#  '../../data/Beverages/600052.jpg',
#  '../../data/Beverages/600437.jpg',
#  '../../data/Soaps/200252.jpg',
#  '../../data/Biscuits/400042.jpg',
#  '../../data/DentalCare/100001.jpg',
#  '../../data/Beverages/600191.jpg',
#  '../../data/Soaps/200370.jpg',
#  '../../data/Snacks/700369.jpg',
#  '../../data/Snacks/700229.jpg',
#  '../../data/Beverages/600185.jpg',
#  '../../data/Beverages/600332.jpg',
#  '../../data/DentalCare/100131.jpg',
#  '../../data/IceCreams/120441.jpg',
#  '../../data/Beverages/600203.jpg',
#  '../../data/Snacks/700439.jpg',
#  '../../data/Beverages/600221.jpg',
#  '../../data/HairCare/300264.jpg',
#  '../../data/Beverages/600298.jpg',
#  '../../data/Snacks/700159.jpg',
#  '../../data/Snacks/700366.jpg',
#  '../../data/Soaps/200045.jpg',
#  '../../data/Soaps/200053.jpg',
#  '../../data/IceCreams/120188.jpg',
#  '../../data/IceCreams/120316.jpg',
#  '../../data/Beverages/600276.jpg',
#  '../../data/Snacks/700112.jpg',
#  '../../data/Biscuits/400322.jpg',
#  '../../data/Beverages/600190.jpg',
#  '../../data/Beverages/600418.jpg',
#  '../../data/Beverages/600349.jpg',
#  '../../data/Snacks/700131.jpg',
#  '../../data/Soaps/200100.jpg',
#  '../../data/Beverages/600344.jpg',
#  '../../data/Beverages/600108.jpg',
#  '../../data/Snacks/700436.jpg',
#  '../../data/DentalCare/200005.jpg',
#  '../../data/Snacks/700368.jpg',
#  '../../data/Soaps/200151.jpg',
#  '../../data/HairCare/300290.jpg',
#  '../../data/DentalCare/300011.jpg',
#  '../../data/Snacks/700212.jpg',
#  '../../data/HairCare/300030.jpg',
#  '../../data/Beverages/600123.jpg',
#  '../../data/Soaps/200369.jpg',
#  '../../data/Beverages/600343.jpg',
#  '../../data/Snacks/700435.jpg',
#  '../../data/Snacks/700026.jpg',
#  '../../data/Beverages/600082.jpg',
#  '../../data/HairCare/300098.jpg',
#  '../../data/Snacks/700444.jpg',
#  '../../data/Snacks/700433.jpg',
#  '../../data/Beverages/600251.jpg',
#  '../../data/HairCare/300284.jpg',
#  '../../data/Snacks/700440.jpg',
#  '../../data/Snacks/700434.jpg',
#  '../../data/Snacks/700179.jpg',
#  '../../data/Snacks/700030.jpg',
#  '../../data/Snacks/700360.jpg',
#  '../../data/SoftDrinks/500275.jpg',
#  '../../data/Soaps/200037.jpg',
#  '../../data/Beverages/600319.jpg',
#  '../../data/DentalCare/200460.jpg',
#  '../../data/Soaps/200365.jpg',
#  '../../data/Beverages/600189.jpg',
#  '../../data/Biscuits/400043.jpg',
#  '../../data/Beverages/600406.jpg',
#  '../../data/HairCare/300335.jpg',
#  '../../data/Beverages/600218.jpg',
#  '../../data/Snacks/700437.jpg',
#  '../../data/DentalCare/100075.jpg',
#  '../../data/Snacks/700182.jpg',
#  '../../data/Snacks/700243.jpg',
#  '../../data/Beverages/600104.jpg',
#  '../../data/Snacks/700155.jpg',
#  '../../data/HairCare/300076.jpg',
#  '../../data/Snacks/700343.jpg',
#  '../../data/Snacks/700190.jpg',
#  '../../data/Snacks/700370.jpg',
#  '../../data/Biscuits/400049.jpg',
#  '../../data/Beverages/600240.jpg',
#  '../../data/Snacks/700371.jpg',
#  '../../data/DentalCare/100171.jpg',
#  '../../data/Soaps/200114.jpg',
#  '../../data/Beverages/600134.jpg',
#  '../../data/HairCare/300281.jpg',
#  '../../data/SoftDrinks/500297.jpg',
#  '../../data/Soaps/200416.jpg',
#  '../../data/Soaps/200163.jpg',
#  '../../data/Soaps/200353.jpg',
#  '../../data/Snacks/700365.jpg',
#  '../../data/Snacks/700207.jpg',
#  '../../data/DentalCare/100164.jpg',
#  '../../data/DentalCare/400001.jpg',
#  '../../data/Soaps/200084.jpg',
#  '../../data/Soaps/200398.jpg',
#  '../../data/Beverages/600280.jpg',
#  '../../data/Snacks/700161.jpg',
#  '../../data/Snacks/700028.jpg',
#  '../../data/SoftDrinks/500330.jpg',
#  '../../data/DentalCare/300005.jpg',
#  '../../data/Soaps/200432.jpg',
#  '../../data/Soaps/200207.jpg',
#  '../../data/Detergents/900323.jpg',
#  '../../data/Beverages/600172.jpg',
#  '../../data/HairCare/300283.jpg',
#  '../../data/DentalCare/100176.jpg',
#  '../../data/IceCreams/120438.jpg',
#  '../../data/Beverages/600337.jpg',
#  '../../data/Snacks/700220.jpg',
#  '../../data/Snacks/700443.jpg',
#  '../../data/Snacks/700024.jpg',
#  '../../data/Snacks/700174.jpg',
#  '../../data/SoftDrinks/500302.jpg',
#  '../../data/DentalCare/100172.jpg',
#  '../../data/Soaps/200010.jpg',
#  '../../data/Soaps/200124.jpg',
#  '../../data/Snacks/700339.jpg',
#  '../../data/DentalCare/100010.jpg',
#  '../../data/Soaps/200378.jpg',
#  '../../data/Soaps/200160.jpg',
#  '../../data/Soaps/200286.jpg',
#  '../../data/Beverages/600007.jpg',
#  '../../data/Snacks/700245.jpg',
#  '../../data/DentalCare/100159.jpg',
#  '../../data/DentalCare/300004.jpg',
#  '../../data/Soaps/200265.jpg',
#  '../../data/Soaps/200422.jpg',
#  '../../data/IceCreams/120183.jpg',
#  '../../data/HairCare/300190.jpg',
#  '../../data/Snacks/700454.jpg',
#  '../../data/SoftDrinks/500163.jpg',
#  '../../data/SoftDrinks/500129.jpg',
#  '../../data/DentalCare/100062.jpg',
#  '../../data/IceCreams/120439.jpg',
#  '../../data/Snacks/700382.jpg',
#  '../../data/Snacks/700453.jpg',
#  '../../data/Soaps/200359.jpg',
#  '../../data/Soaps/200335.jpg',
#  '../../data/Beverages/600064.jpg',
#  '../../data/Beverages/600103.jpg',
#  '../../data/DentalCare/100002.jpg',
#  '../../data/Beverages/600368.jpg',
#  '../../data/Beverages/600192.jpg',
#  '../../data/DentalCare/400006.jpg',
#  '../../data/DentalCare/100007.jpg',
#  '../../data/Beverages/600198.jpg',
#  '../../data/Beverages/600136.jpg',
#  '../../data/Snacks/700032.jpg',
#  '../../data/Snacks/700031.jpg',
#  '../../data/Snacks/700438.jpg',
#  '../../data/DentalCare/100137.jpg',
#  '../../data/DentalCare/200001.jpg',
#  '../../data/DentalCare/300007.jpg',
#  '../../data/HairCare/300349.jpg',
#  '../../data/Snacks/700189.jpg',
#  '../../data/Snacks/700001.jpg',
#  '../../data/Snacks/700358.jpg',
#  '../../data/Biscuits/400027.jpg',
#  '../../data/SoftDrinks/500363.jpg',
#  '../../data/Soaps/200223.jpg',
#  '../../data/Beverages/600292.jpg',
#  '../../data/Beverages/600219.jpg',
#  '../../data/Beverages/600120.jpg',
#  '../../data/Snacks/700156.jpg',
#  '../../data/DentalCare/200491.jpg',
#  '../../data/SoftDrinks/500125.jpg',
#  '../../data/Soaps/200293.jpg',
#  '../../data/Soaps/200187.jpg',
#  '../../data/Beverages/600157.jpg',
#  '../../data/Beverages/600026.jpg',
#  '../../data/Beverages/600265.jpg',
#  '../../data/HairCare/300080.jpg',
#  '../../data/HairCare/300064.jpg',
#  '../../data/HairCare/300173.jpg',
#  '../../data/Snacks/700342.jpg',
#  '../../data/Biscuits/400028.jpg',
#  '../../data/Biscuits/400071.jpg',
#  '../../data/DentalCare/100111.jpg',
#  '../../data/DentalCare/200458.jpg',
#  '../../data/Beverages/600139.jpg',
#  '../../data/Beverages/600301.jpg',
#  '../../data/Snacks/700380.jpg',
#  '../../data/Snacks/700214.jpg',
#  '../../data/Snacks/700201.jpg',
#  '../../data/DentalCare/300010.jpg',
#  '../../data/Beverages/600041.jpg',
#  '../../data/HairCare/300415.jpg',
#  '../../data/HairCare/300354.jpg',
#  '../../data/Snacks/700160.jpg',
#  '../../data/Snacks/700170.jpg',
#  '../../data/Snacks/700379.jpg',
#  '../../data/DentalCare/100177.jpg',
#  '../../data/DentalCare/400009.jpg',
#  '../../data/DentalCare/100017.jpg',
#  '../../data/Soaps/200400.jpg',
#  '../../data/Beverages/600122.jpg',
#  '../../data/Beverages/600273.jpg',
#  '../../data/Snacks/700449.jpg',
#  '../../data/Snacks/700450.jpg',
#  '../../data/Snacks/700397.jpg',
#  '../../data/Biscuits/400016.jpg',
#  '../../data/DentalCare/200455.jpg',
#  '../../data/DentalCare/100170.jpg',
#  '../../data/Soaps/200004.jpg',
#  '../../data/Soaps/200169.jpg',
#  '../../data/Beverages/600035.jpg',
#  '../../data/Beverages/600361.jpg',
#  '../../data/HairCare/300199.jpg',
#  '../../data/HairCare/300061.jpg',
#  '../../data/Snacks/700445.jpg',
#  '../../data/Snacks/700037.jpg',
#  '../../data/Snacks/700378.jpg',
#  '../../data/Soaps/200145.jpg',
#  '../../data/Soaps/200267.jpg',
#  '../../data/Soaps/200424.jpg',
#  '../../data/Soaps/200291.jpg',
#  '../../data/Beverages/600008.jpg',
#  '../../data/Beverages/600374.jpg',
#  '../../data/Snacks/700047.jpg',
#  '../../data/SoftDrinks/500489.jpg',
#  '../../data/Soaps/200050.jpg',
#  '../../data/Beverages/600186.jpg',
#  '../../data/Beverages/600160.jpg',
#  '../../data/Beverages/600266.jpg',
#  '../../data/HairCare/300247.jpg',
#  '../../data/HairCare/300197.jpg',
#  '../../data/Biscuits/400023.jpg',
#  '../../data/SoftDrinks/500142.jpg',
#  '../../data/SoftDrinks/500252.jpg',
#  '../../data/SoftDrinks/500276.jpg',
#  '../../data/DentalCare/100141.jpg',
#  '../../data/Soaps/200431.jpg',
#  '../../data/Soaps/200086.jpg',
#  '../../data/Soaps/200356.jpg',
#  '../../data/Soaps/200448.jpg',
#  '../../data/Soaps/200397.jpg',
#  '../../data/Beverages/600284.jpg',
#  '../../data/Snacks/700383.jpg',
#  '../../data/Snacks/700038.jpg',
#  '../../data/Snacks/700236.jpg',
#  '../../data/Snacks/700381.jpg',
#  '../../data/Biscuits/400004.jpg',
#  '../../data/Biscuits/400001.jpg',
#  '../../data/DentalCare/200499.jpg',
#  '../../data/DentalCare/100085.jpg',
#  '../../data/Soaps/200333.jpg',
#  '../../data/Soaps/200125.jpg',
#  '../../data/Beverages/600071.jpg',
#  '../../data/Beverages/600101.jpg',
#  '../../data/HairCare/300149.jpg',
#  '../../data/HairCare/300367.jpg',
#  '../../data/Snacks/700163.jpg',
#  '../../data/Snacks/700456.jpg',
#  '../../data/DentalCare/200483.jpg',
#  '../../data/DentalCare/100003.jpg',
#  '../../data/DentalCare/100076.jpg',
#  '../../data/Soaps/200358.jpg',
#  '../../data/Soaps/200446.jpg',
#  '../../data/Beverages/600169.jpg',
#  '../../data/Beverages/600420.jpg',
#  '../../data/Beverages/600102.jpg',
#  '../../data/Beverages/600340.jpg',
#  '../../data/HairCare/300320.jpg',
#  '../../data/Snacks/700384.jpg',
#  '../../data/Snacks/700043.jpg',
#  '../../data/Biscuits/400026.jpg',
#  '../../data/DentalCare/100128.jpg',
#  '../../data/DentalCare/100100.jpg',
#  '../../data/DentalCare/200457.jpg',
#  '../../data/Soaps/200336.jpg',
#  '../../data/Soaps/200001.jpg',
#  '../../data/Soaps/200403.jpg',
#  '../../data/Beverages/600046.jpg',
#  '../../data/Beverages/600303.jpg',
#  '../../data/Beverages/600125.jpg',
#  '../../data/HairCare/300337.jpg',
#  '../../data/Snacks/700135.jpg',
#  '../../data/Snacks/700410.jpg',
#  '../../data/Snacks/700213.jpg',
#  '../../data/Snacks/700398.jpg',
#  '../../data/Snacks/700354.jpg',
#  '../../data/Snacks/700040.jpg',
#  '../../data/Biscuits/400081.jpg',
#  '../../data/Chocolates/800306.jpg',
#  '../../data/SoftDrinks/500200.jpg',
#  '../../data/SoftDrinks/500231.jpg',
#  '../../data/SoftDrinks/500311.jpg',
#  '../../data/SoftDrinks/500149.jpg',
#  '../../data/DentalCare/100053.jpg',
#  '../../data/DentalCare/300002.jpg',
#  '../../data/Soaps/200005.jpg',
#  '../../data/Soaps/200185.jpg',
#  '../../data/Soaps/200423.jpg',
#  '../../data/Beverages/600394.jpg',
#  '../../data/Beverages/600076.jpg',
#  '../../data/Beverages/600402.jpg',
#  '../../data/HairCare/300336.jpg',
#  '../../data/Snacks/700225.jpg',
#  '../../data/Snacks/700364.jpg',
#  '../../data/Snacks/700042.jpg',
#  '../../data/SoftDrinks/500104.jpg',
#  '../../data/DentalCare/100005.jpg',
#  '../../data/Soaps/200228.jpg',
#  '../../data/Soaps/200332.jpg',
#  '../../data/Soaps/200146.jpg',
#  '../../data/Soaps/200407.jpg',
#  '../../data/Soaps/200337.jpg',
#  '../../data/Soaps/200047.jpg',
#  '../../data/Beverages/600100.jpg',
#  '../../data/HairCare/300442.jpg',
#  '../../data/Snacks/700044.jpg',
#  '../../data/Snacks/700396.jpg',
#  '../../data/Snacks/700413.jpg',
#  '../../data/Snacks/700228.jpg',
#  '../../data/SoftDrinks/500241.jpg',
#  '../../data/SoftDrinks/500312.jpg',
#  '../../data/DentalCare/200013.jpg',
#  '../../data/Beverages/600215.jpg',
#  '../../data/HairCare/300406.jpg',
#  '../../data/HairCare/300203.jpg',
#  '../../data/Snacks/700442.jpg',
#  '../../data/Biscuits/400024.jpg',
#  '../../data/DentalCare/100078.jpg',
#  '../../data/DentalCare/100037.jpg',
#  '../../data/DentalCare/100018.jpg',
#  '../../data/Soaps/200402.jpg',
#  '../../data/Soaps/200445.jpg',
#  '../../data/Soaps/200206.jpg',
#  '../../data/Soaps/200137.jpg',
#  '../../data/IceCreams/120182.jpg',
#  '../../data/Beverages/600314.jpg',
#  '../../data/HairCare/300324.jpg',
#  '../../data/HairCare/300176.jpg',
#  '../../data/HairCare/300433.jpg',
#  '../../data/Snacks/700004.jpg',
#  '../../data/Snacks/700231.jpg',
#  '../../data/Snacks/700362.jpg',
#  '../../data/Snacks/700033.jpg',
#  '../../data/Biscuits/400031.jpg',
#  '../../data/SoftDrinks/500308.jpg',
#  '../../data/DentalCare/200462.jpg',
#  '../../data/DentalCare/100160.jpg',
#  '../../data/Soaps/200088.jpg',
#  '../../data/Soaps/200246.jpg',
#  '../../data/Soaps/200061.jpg',
#  '../../data/Beverages/600234.jpg',
#  '../../data/Beverages/600099.jpg',
#  '../../data/Beverages/600196.jpg',
#  '../../data/Beverages/600217.jpg',
#  '../../data/HairCare/300341.jpg',
#  '../../data/HairCare/300210.jpg',
#  '../../data/HairCare/300131.jpg',
#  '../../data/Biscuits/400165.jpg',
#  '../../data/SoftDrinks/500157.jpg',
#  '../../data/SoftDrinks/500226.jpg',
#  '../../data/SoftDrinks/500383.jpg',
#  '../../data/SoftDrinks/500162.jpg',
#  '../../data/SoftDrinks/500326.jpg',
#  '../../data/SoftDrinks/500224.jpg',
#  '../../data/SoftDrinks/500131.jpg',
#  '../../data/DentalCare/100032.jpg',
#  '../../data/DentalCare/300001.jpg',
#  '../../data/DentalCare/100020.jpg',
#  '../../data/DentalCare/100043.jpg',
#  '../../data/DentalCare/100014.jpg',
#  '../../data/DentalCare/400011.jpg',
#  '../../data/DentalCare/100089.jpg',
#  '../../data/Soaps/200065.jpg',
#  '../../data/Soaps/200392.jpg',
#  '../../data/Soaps/200434.jpg',
#  '../../data/HairCare/300208.jpg',
#  '../../data/HairCare/300491.jpg',
#  '../../data/Snacks/700451.jpg',
#  '../../data/Snacks/700359.jpg',
#  '../../data/Biscuits/400008.jpg',
#  '../../data/SoftDrinks/500301.jpg',
#  '../../data/SoftDrinks/500299.jpg',
#  '../../data/DentalCare/100038.jpg',
#  '../../data/DentalCare/100066.jpg',
#  '../../data/DentalCare/100134.jpg',
#  '../../data/DentalCare/200473.jpg',
#  '../../data/Soaps/200253.jpg',
#  '../../data/Soaps/200305.jpg',
#  '../../data/Soaps/200197.jpg',
#  '../../data/Soaps/200181.jpg',
#  '../../data/Beverages/600116.jpg',
#  '../../data/Beverages/600206.jpg',
#  '../../data/Beverages/600316.jpg',
#  '../../data/Beverages/600364.jpg',
#  '../../data/Beverages/600419.jpg',
#  '../../data/HairCare/300059.jpg',
#  '../../data/HairCare/300038.jpg',
#  '../../data/HairCare/300268.jpg',
#  '../../data/HairCare/300289.jpg',
#  '../../data/HairCare/300502.jpg',
#  '../../data/HairCare/300116.jpg',
#  '../../data/HairCare/300505.jpg',
#  '../../data/Snacks/700051.jpg',
#  '../../data/SoftDrinks/500413.jpg',
#  '../../data/DentalCare/100098.jpg',
#  '../../data/DentalCare/100051.jpg',
#  '../../data/Soaps/200326.jpg',
#  '../../data/Soaps/200395.jpg',
#  '../../data/Soaps/200361.jpg',
#  '../../data/Soaps/200026.jpg',
#  '../../data/Beverages/600267.jpg',
#  '../../data/Beverages/600063.jpg',
#  '../../data/Beverages/600054.jpg',
#  '../../data/HairCare/300218.jpg',
#  '../../data/HairCare/300040.jpg',
#  '../../data/Biscuits/400015.jpg',
#  '../../data/Biscuits/400021.jpg',
#  '../../data/SoftDrinks/500186.jpg',
#  '../../data/DentalCare/100040.jpg',
#  '../../data/DentalCare/100039.jpg',
#  '../../data/DentalCare/100093.jpg',
#  '../../data/DentalCare/100084.jpg',
#  '../../data/Soaps/200368.jpg',
#  '../../data/Soaps/200031.jpg',
#  '../../data/Soaps/200450.jpg',
#  '../../data/Soaps/200212.jpg',
#  '../../data/Soaps/200112.jpg',
#  '../../data/Beverages/600321.jpg',
#  '../../data/HairCare/300209.jpg',
#  '../../data/HairCare/300240.jpg',
#  '../../data/HairCare/300323.jpg',
#  '../../data/Snacks/700457.jpg',
#  '../../data/Snacks/700232.jpg',
#  '../../data/Snacks/700448.jpg',
#  '../../data/Snacks/700409.jpg',
#  '../../data/Snacks/700376.jpg',
#  '../../data/Biscuits/400010.jpg',
#  '../../data/SoftDrinks/500439.jpg',
#  '../../data/SoftDrinks/500429.jpg',
#  '../../data/DentalCare/100092.jpg',
#  '../../data/DentalCare/200451.jpg',
#  '../../data/DentalCare/300014.jpg',
#  '../../data/DentalCare/100044.jpg',
#  '../../data/DentalCare/200014.jpg',
#  '../../data/Soaps/200312.jpg',
#  '../../data/Soaps/200070.jpg',
#  '../../data/Soaps/200409.jpg',
#  '../../data/IceCreams/120306.jpg',
#  '../../data/Beverages/600244.jpg',
#  '../../data/Beverages/600274.jpg',
#  '../../data/Beverages/600019.jpg',
#  '../../data/Beverages/600313.jpg',
#  '../../data/Beverages/600432.jpg',
#  '../../data/HairCare/300204.jpg',
#  '../../data/HairCare/300090.jpg',
#  '../../data/HairCare/300455.jpg',
#  '../../data/HairCare/300359.jpg',
#  '../../data/HairCare/300054.jpg',
#  '../../data/Snacks/700191.jpg',
#  '../../data/Snacks/700414.jpg',
#  '../../data/Snacks/700447.jpg',
#  '../../data/Snacks/700171.jpg',
#  '../../data/Snacks/700239.jpg',
#  '../../data/SoftDrinks/500197.jpg',
#  '../../data/DentalCare/100168.jpg',
#  '../../data/DentalCare/100173.jpg',
#  '../../data/DentalCare/100015.jpg',
#  '../../data/DentalCare/100004.jpg',
#  '../../data/DentalCare/100063.jpg',
#  '../../data/DentalCare/400017.jpg',
#  '../../data/Soaps/200348.jpg',
#  '../../data/Soaps/200290.jpg',
#  '../../data/Soaps/200224.jpg',
#  '../../data/Soaps/200014.jpg',
#  '../../data/IceCreams/120185.jpg',
#  '../../data/Beverages/600175.jpg',
#  '../../data/Beverages/600306.jpg',
#  '../../data/Beverages/600079.jpg',
#  '../../data/Beverages/600174.jpg',
#  '../../data/Beverages/600005.jpg',
#  '../../data/HairCare/300485.jpg',
#  '../../data/HairCare/300288.jpg',
#  '../../data/HairCare/300060.jpg',
#  '../../data/HairCare/300237.jpg',
#  '../../data/HairCare/300249.jpg',
#  '../../data/HairCare/300291.jpg',
#  '../../data/HairCare/300211.jpg',
#  '../../data/HairCare/300088.jpg',
#  '../../data/HairCare/300094.jpg',
#  '../../data/Snacks/700240.jpg',
#  '../../data/Snacks/700374.jpg',
#  '../../data/SoftDrinks/500491.jpg',
#  '../../data/DentalCare/100065.jpg',
#  '../../data/DentalCare/100077.jpg',
#  '../../data/DentalCare/100088.jpg',
#  '../../data/Soaps/200012.jpg',
#  '../../data/Soaps/200441.jpg',
#  '../../data/Soaps/200120.jpg',
#  '../../data/Soaps/200021.jpg',
#  '../../data/Soaps/200427.jpg',
#  '../../data/Soaps/200444.jpg',
#  '../../data/Soaps/200316.jpg',
#  '../../data/Soaps/200071.jpg',
#  '../../data/Soaps/200193.jpg',
#  '../../data/Soaps/200324.jpg',
#  '../../data/IceCreams/120390.jpg',
#  '../../data/Beverages/600148.jpg',
#  '../../data/Beverages/600180.jpg',
#  '../../data/Beverages/600373.jpg',
#  '../../data/Beverages/600015.jpg',
#  '../../data/Beverages/600410.jpg',
#  '../../data/HairCare/300154.jpg',
#  '../../data/HairCare/300263.jpg',
#  '../../data/HairCare/300102.jpg',
#  '../../data/HairCare/300099.jpg',
#  '../../data/HairCare/300282.jpg',
#  '../../data/Snacks/700187.jpg',
#  '../../data/Snacks/700046.jpg',
#  '../../data/Snacks/700166.jpg',
#  '../../data/Snacks/700412.jpg',
#  '../../data/Snacks/700193.jpg',
#  '../../data/Snacks/700441.jpg',
#  '../../data/Biscuits/400012.jpg',
#  '../../data/Biscuits/400003.jpg',
#  '../../data/Biscuits/400032.jpg',
#  '../../data/SoftDrinks/500398.jpg',
#  '../../data/SoftDrinks/500416.jpg',
#  '../../data/DentalCare/100012.jpg',
#  '../../data/DentalCare/100153.jpg',
#  '../../data/DentalCare/100169.jpg',
#  '../../data/Soaps/200251.jpg',
#  '../../data/Soaps/200013.jpg',
#  '../../data/Soaps/200119.jpg',
#  '../../data/Soaps/200259.jpg',
#  '../../data/Soaps/200034.jpg',
#  '../../data/Soaps/200192.jpg',
#  '../../data/Soaps/200211.jpg',
#  '../../data/Soaps/200219.jpg',
#  '../../data/Soaps/200052.jpg',
#  '../../data/Soaps/200159.jpg',
#  '../../data/Soaps/200292.jpg',
#  '../../data/Beverages/600304.jpg',
#  '../../data/Beverages/600390.jpg',
#  '../../data/Beverages/600012.jpg',
#  '../../data/Beverages/600421.jpg',
#  '../../data/Beverages/600403.jpg',
#  '../../data/Beverages/600422.jpg',
#  '../../data/HairCare/300075.jpg',
#  '../../data/Snacks/700446.jpg',
#  '../../data/Snacks/700172.jpg',
#  '../../data/Snacks/700406.jpg',
#  '../../data/SoftDrinks/500470.jpg',
#  '../../data/SoftDrinks/500127.jpg',
#  '../../data/DentalCare/100184.jpg',
#  '../../data/DentalCare/200018.jpg',
#  '../../data/DentalCare/300009.jpg',
#  '../../data/DentalCare/400016.jpg',
#  '../../data/DentalCare/100179.jpg',
#  '../../data/Soaps/200129.jpg',
#  '../../data/Soaps/200245.jpg',
#  '../../data/Beverages/600363.jpg',
#  '../../data/Beverages/600309.jpg',
#  '../../data/Beverages/600386.jpg',
#  '../../data/Beverages/600133.jpg',
#  '../../data/Beverages/600355.jpg',
#  '../../data/Beverages/600092.jpg',
#  '../../data/HairCare/300454.jpg',
#  '../../data/HairCare/300037.jpg',
#  '../../data/HairCare/300312.jpg',
#  '../../data/HairCare/300117.jpg',
#  '../../data/Snacks/700041.jpg',
#  '../../data/Snacks/700180.jpg',
#  '../../data/Snacks/700205.jpg',
#  '../../data/Biscuits/400019.jpg',
#  '../../data/SoftDrinks/500435.jpg',
#  '../../data/SoftDrinks/500036.jpg',
#  '../../data/SoftDrinks/500176.jpg',
#  '../../data/SoftDrinks/500141.jpg',
#  '../../data/SoftDrinks/500073.jpg',
#  '../../data/SoftDrinks/500251.jpg',
#  '../../data/DentalCare/200501.jpg',
#  '../../data/DentalCare/100009.jpg',
#  '../../data/DentalCare/100129.jpg',
#  '../../data/DentalCare/400007.jpg',
#  '../../data/DentalCare/200476.jpg',
#  '../../data/DentalCare/100156.jpg',
#  '../../data/DentalCare/100143.jpg',
#  '../../data/DentalCare/100067.jpg',
#  '../../data/Soaps/200168.jpg',
#  '../../data/Soaps/200075.jpg',
#  '../../data/Beverages/600224.jpg',
#  '../../data/Beverages/600423.jpg',
#  '../../data/Beverages/600336.jpg',
#  '../../data/Beverages/600439.jpg',
#  '../../data/Beverages/600427.jpg',
#  '../../data/HairCare/300114.jpg',
#  '../../data/HairCare/300420.jpg',
#  '../../data/HairCare/300297.jpg',
#  '../../data/HairCare/300221.jpg',
#  '../../data/HairCare/300241.jpg',
#  '../../data/HairCare/300246.jpg',
#  '../../data/HairCare/300338.jpg',
#  '../../data/HairCare/300328.jpg',
#  '../../data/HairCare/300346.jpg',
#  '../../data/HairCare/300292.jpg',
#  '../../data/HairCare/300343.jpg',
#  '../../data/HairCare/300224.jpg',
#  '../../data/Snacks/700110.jpg',
#  '../../data/Snacks/700209.jpg',
#  '../../data/Snacks/700168.jpg',
#  '../../data/Snacks/700206.jpg',
#  '../../data/SoftDrinks/500239.jpg',
#  '../../data/SoftDrinks/500126.jpg',
#  '../../data/SoftDrinks/500214.jpg',
#  '../../data/SoftDrinks/500407.jpg',
#  '../../data/SoftDrinks/500216.jpg',
#  '../../data/SoftDrinks/500069.jpg',
#  '../../data/DentalCare/100183.jpg',
#  '../../data/DentalCare/200497.jpg',
#  '../../data/DentalCare/300008.jpg',
#  '../../data/DentalCare/100091.jpg',
#  '../../data/DentalCare/100021.jpg',
#  '../../data/DentalCare/100105.jpg',
#  '../../data/DentalCare/100057.jpg',
#  '../../data/DentalCare/100008.jpg',
#  '../../data/DentalCare/100031.jpg',
#  '../../data/Soaps/200313.jpg',
#  '../../data/Soaps/200002.jpg',
#  '../../data/Soaps/200131.jpg',
#  '../../data/Soaps/200036.jpg',
#  '../../data/Soaps/200239.jpg',
#  '../../data/Soaps/200440.jpg',
#  '../../data/Beverages/600285.jpg',
#  '../../data/Beverages/600262.jpg',
#  '../../data/Beverages/600392.jpg',
#  '../../data/Beverages/600042.jpg',
#  '../../data/Beverages/600034.jpg',
#  '../../data/HairCare/300091.jpg',
#  '../../data/HairCare/300258.jpg',
#  '../../data/HairCare/300358.jpg',
#  '../../data/HairCare/300275.jpg',
#  '../../data/HairCare/300155.jpg',
#  '../../data/Snacks/700108.jpg',
#  '../../data/Snacks/700395.jpg',
#  '../../data/Snacks/700352.jpg',
#  '../../data/Snacks/700012.jpg',
#  '../../data/Snacks/700188.jpg',
#  '../../data/Snacks/700035.jpg',
#  '../../data/Biscuits/400007.jpg',
#  '../../data/SoftDrinks/500442.jpg',
#  '../../data/SoftDrinks/500237.jpg',
#  '../../data/DentalCare/200020.jpg',
#  '../../data/DentalCare/100161.jpg',
#  '../../data/DentalCare/100109.jpg',
#  '../../data/DentalCare/400015.jpg',
#  '../../data/DentalCare/100069.jpg',
#  '../../data/DentalCare/100186.jpg',
#  '../../data/DentalCare/100182.jpg',
#  '../../data/DentalCare/100127.jpg',
#  '../../data/DentalCare/100178.jpg',
#  '../../data/DentalCare/100048.jpg',
#  '../../data/Soaps/200244.jpg',
#  '../../data/Soaps/200133.jpg',
#  '../../data/Soaps/200209.jpg',
#  '../../data/Soaps/200296.jpg',
#  '../../data/Soaps/200136.jpg',
#  '../../data/Soaps/200076.jpg',
#  '../../data/Soaps/200308.jpg',
#  '../../data/Soaps/200306.jpg',
#  '../../data/Soaps/200260.jpg',
#  '../../data/Soaps/200367.jpg',
#  '../../data/Soaps/200041.jpg',
#  '../../data/Beverages/600220.jpg',
#  '../../data/Beverages/600061.jpg',
#  '../../data/Beverages/600167.jpg',
#  '../../data/Beverages/600308.jpg',
#  '../../data/Beverages/600335.jpg',
#  '../../data/Beverages/600345.jpg',
#  '../../data/HairCare/300029.jpg',
#  '../../data/HairCare/300071.jpg',
#  '../../data/HairCare/300331.jpg',
#  '../../data/HairCare/300065.jpg',
#  '../../data/HairCare/300494.jpg',
#  '../../data/Snacks/700010.jpg',
#  '../../data/Snacks/700227.jpg',
#  '../../data/Biscuits/400013.jpg',
#  '../../data/Biscuits/400011.jpg',
#  '../../data/Biscuits/400267.jpg',
#  '../../data/SoftDrinks/500371.jpg',
#  '../../data/SoftDrinks/500101.jpg',
#  '../../data/SoftDrinks/500492.jpg',
#  '../../data/SoftDrinks/500243.jpg',
#  '../../data/DentalCare/100035.jpg',
#  '../../data/DentalCare/400013.jpg',
#  '../../data/DentalCare/400008.jpg',
#  '../../data/DentalCare/100058.jpg',
#  '../../data/DentalCare/100133.jpg',
#  '../../data/DentalCare/100135.jpg',
#  '../../data/DentalCare/100185.jpg',
#  '../../data/DentalCare/100099.jpg',
#  '../../data/DentalCare/100130.jpg',
#  '../../data/DentalCare/100011.jpg',
#  '../../data/DentalCare/200492.jpg',
#  '../../data/DentalCare/100086.jpg',
#  '../../data/DentalCare/100050.jpg',
#  '../../data/DentalCare/200459.jpg',
#  '../../data/DentalCare/100122.jpg',
#  '../../data/Soaps/200172.jpg',
#  '../../data/Soaps/200095.jpg',
#  '../../data/Soaps/200215.jpg',
#  '../../data/Soaps/200362.jpg',
#  '../../data/Soaps/200183.jpg',
#  '../../data/Soaps/200171.jpg',
#  '../../data/Beverages/600369.jpg',
#  '../../data/Beverages/600166.jpg',
#  '../../data/Beverages/600044.jpg',
#  '../../data/Beverages/600001.jpg',
#  '../../data/Beverages/600325.jpg',
#  '../../data/Beverages/600109.jpg',
#  '../../data/Beverages/600241.jpg',
#  '../../data/Beverages/600222.jpg',
#  '../../data/Beverages/600411.jpg',
#  '../../data/Beverages/600429.jpg',
#  '../../data/Beverages/600105.jpg',
#  '../../data/Beverages/600152.jpg',
#  '../../data/HairCare/300119.jpg',
#  '../../data/HairCare/300348.jpg',
#  '../../data/HairCare/300425.jpg',
#  '../../data/HairCare/300347.jpg',
#  '../../data/HairCare/300233.jpg',
#  '../../data/HairCare/300063.jpg',
#  '../../data/HairCare/300189.jpg',
#  '../../data/Snacks/700007.jpg',
#  '../../data/Snacks/700176.jpg',
#  '../../data/Snacks/700350.jpg',
#  '../../data/Biscuits/400056.jpg',
#  '../../data/Biscuits/400014.jpg',
#  '../../data/Biscuits/400033.jpg',
#  '../../data/Chocolates/800241.jpg',
#  '../../data/SoftDrinks/500071.jpg',
#  '../../data/SoftDrinks/500307.jpg',
#  '../../data/SoftDrinks/500063.jpg',
#  '../../data/SoftDrinks/500460.jpg',
#  '../../data/SoftDrinks/500179.jpg',
#  '../../data/DentalCare/200495.jpg',
#  '../../data/DentalCare/100054.jpg',
#  '../../data/DentalCare/100162.jpg',
#  '../../data/Soaps/200220.jpg',
#  '../../data/Soaps/200198.jpg',
#  '../../data/Soaps/200393.jpg',
#  '../../data/Soaps/200144.jpg',
#  '../../data/Soaps/200139.jpg',
#  '../../data/Soaps/200404.jpg',
#  '../../data/Soaps/200344.jpg',
#  '../../data/Soaps/200090.jpg',
#  '../../data/Beverages/600080.jpg',
#  '../../data/Beverages/600259.jpg',
#  '../../data/Beverages/600257.jpg',
#  '../../data/Beverages/600112.jpg',
#  '../../data/Beverages/600097.jpg',
#  '../../data/Beverages/600110.jpg',
#  '../../data/Beverages/600346.jpg',
#  '../../data/Beverages/600201.jpg',
#  '../../data/Beverages/600275.jpg',
#  '../../data/Beverages/600195.jpg',
#  '../../data/Beverages/600069.jpg',
#  '../../data/HairCare/300156.jpg',
#  '../../data/HairCare/300503.jpg',
#  '../../data/HairCare/300041.jpg',
#  '../../data/HairCare/300243.jpg',
#  '../../data/HairCare/300257.jpg',
#  '../../data/HairCare/300096.jpg',
#  '../../data/Snacks/700079.jpg',
#  '../../data/Snacks/700411.jpg',
#  '../../data/Snacks/700361.jpg',
#  '../../data/Snacks/700157.jpg',
#  '../../data/Biscuits/400022.jpg',
#  '../../data/Biscuits/400034.jpg',
#  '../../data/SoftDrinks/500321.jpg',
#  '../../data/SoftDrinks/500145.jpg',
#  '../../data/SoftDrinks/500170.jpg',
#  '../../data/SoftDrinks/500019.jpg',
#  '../../data/SoftDrinks/500003.jpg',
#  '../../data/SoftDrinks/500412.jpg',
#  '../../data/SoftDrinks/500156.jpg',
#  '../../data/SoftDrinks/500476.jpg',
#  '../../data/SoftDrinks/500165.jpg',
#  '../../data/DentalCare/100154.jpg',
#  '../../data/DentalCare/100019.jpg',
#  '../../data/DentalCare/100033.jpg',
#  '../../data/DentalCare/200470.jpg',
#  '../../data/DentalCare/100016.jpg',
#  '../../data/DentalCare/100155.jpg',
#  '../../data/DentalCare/100028.jpg',
#  '../../data/DentalCare/100136.jpg',
#  '../../data/DentalCare/100110.jpg',
#  '../../data/Soaps/200027.jpg',
#  '../../data/Soaps/200015.jpg',
#  '../../data/Soaps/200074.jpg',
#  '../../data/Soaps/200357.jpg',
#  '../../data/Soaps/200107.jpg',
#  '../../data/Soaps/200405.jpg',
#  '../../data/Soaps/200218.jpg',
#  '../../data/Soaps/200248.jpg',
#  '../../data/Soaps/200035.jpg',
#  '../../data/Soaps/200321.jpg',
#  '../../data/Soaps/200081.jpg',
#  '../../data/Soaps/200135.jpg',
#  '../../data/Soaps/200083.jpg',
#  '../../data/Soaps/200282.jpg',
#  '../../data/Soaps/200099.jpg',
#  '../../data/IceCreams/120413.jpg',
#  '../../data/IceCreams/120177.jpg',
#  '../../data/IceCreams/120507.jpg',
#  '../../data/Beverages/600197.jpg',
#  '../../data/Beverages/600324.jpg',
#  '../../data/Beverages/600396.jpg',
#  '../../data/Beverages/600164.jpg',
#  '../../data/HairCare/300377.jpg',
#  '../../data/HairCare/300081.jpg',
#  '../../data/HairCare/300311.jpg',
#  '../../data/HairCare/300465.jpg',
#  '../../data/HairCare/300310.jpg',
#  '../../data/Snacks/700029.jpg',
#  '../../data/Snacks/700022.jpg',
#  '../../data/Snacks/700223.jpg',
#  '../../data/Biscuits/400035.jpg',
#  '../../data/SoftDrinks/500211.jpg',
#  '../../data/SoftDrinks/500498.jpg',
#  '../../data/SoftDrinks/500474.jpg',
#  '../../data/SoftDrinks/500270.jpg',
#  '../../data/SoftDrinks/500121.jpg',
#  '../../data/SoftDrinks/500207.jpg',
#  '../../data/SoftDrinks/500194.jpg',
#  '../../data/DentalCare/100060.jpg',
#  '../../data/DentalCare/100061.jpg',
#  '../../data/DentalCare/100095.jpg',
#  '../../data/DentalCare/100126.jpg',
#  '../../data/DentalCare/100157.jpg',
#  '../../data/DentalCare/100023.jpg',
#  '../../data/Soaps/200170.jpg',
#  '../../data/Soaps/200276.jpg',
#  '../../data/Soaps/200030.jpg',
#  '../../data/Soaps/200152.jpg',
#  '../../data/Soaps/200436.jpg',
#  '../../data/Soaps/200175.jpg',
#  '../../data/Soaps/200271.jpg',
#  '../../data/Soaps/200364.jpg',
#  '../../data/Soaps/200073.jpg',
#  '../../data/Soaps/200430.jpg',
#  '../../data/Soaps/200150.jpg',
#  '../../data/Soaps/200178.jpg',
#  '../../data/Soaps/200017.jpg',
#  '../../data/Soaps/200264.jpg',
#  '../../data/Soaps/200179.jpg',
#  '../../data/Soaps/200158.jpg',
#  '../../data/Soaps/200101.jpg',
#  '../../data/Soaps/200191.jpg',
#  '../../data/Soaps/200122.jpg',
#  '../../data/IceCreams/120308.jpg',
#  '../../data/Beverages/600090.jpg',
#  '../../data/Beverages/600193.jpg',
#  '../../data/Beverages/600021.jpg',
#  '../../data/Beverages/600381.jpg',
#  '../../data/Beverages/600385.jpg',
#  '../../data/Beverages/600407.jpg',
#  '../../data/Beverages/600121.jpg',
#  '../../data/Beverages/600226.jpg',
#  '../../data/Beverages/600341.jpg',
#  '../../data/Beverages/600232.jpg',
#  '../../data/Beverages/600414.jpg',
#  '../../data/Beverages/600354.jpg',
#  '../../data/Beverages/600413.jpg',
#  '../../data/Beverages/600409.jpg',
#  '../../data/Beverages/600328.jpg',
#  '../../data/Beverages/600137.jpg',
#  '../../data/Beverages/600032.jpg',
#  '../../data/HairCare/300083.jpg',
#  '../../data/HairCare/300480.jpg',
#  '../../data/HairCare/300351.jpg',
#  '../../data/HairCare/300482.jpg',
#  '../../data/HairCare/300113.jpg',
#  '../../data/HairCare/300078.jpg',
#  '../../data/HairCare/300441.jpg',
#  '../../data/HairCare/300392.jpg',
#  '../../data/HairCare/300108.jpg',
#  '../../data/HairCare/300049.jpg',
#  '../../data/Snacks/700186.jpg',
#  '../../data/Snacks/700241.jpg',
#  '../../data/Snacks/700177.jpg',
#  '../../data/Biscuits/400017.jpg',
#  '../../data/Chocolates/800203.jpg',
#  '../../data/SoftDrinks/500120.jpg',
#  '../../data/SoftDrinks/500026.jpg',
#  '../../data/SoftDrinks/500389.jpg',
#  '../../data/SoftDrinks/500468.jpg',
#  '../../data/SoftDrinks/500242.jpg',
#  '../../data/SoftDrinks/500393.jpg',
#  '../../data/SoftDrinks/500055.jpg',
#  '../../data/SoftDrinks/500469.jpg',
#  '../../data/SoftDrinks/500130.jpg',
#  '../../data/DentalCare/100006.jpg',
#  '../../data/DentalCare/100042.jpg',
#  '../../data/DentalCare/100097.jpg',
#  '../../data/DentalCare/200012.jpg',
#  '../../data/DentalCare/100064.jpg',
#  '../../data/DentalCare/100096.jpg',
#  '../../data/DentalCare/200494.jpg',
#  '../../data/DentalCare/100025.jpg',
#  '../../data/DentalCare/100059.jpg',
#  '../../data/DentalCare/100145.jpg',
#  '../../data/DentalCare/100052.jpg',
#  '../../data/Soaps/200147.jpg',
#  '../../data/Soaps/200380.jpg',
#  '../../data/Soaps/200363.jpg',
#  '../../data/Soaps/200355.jpg',
#  '../../data/Soaps/200261.jpg',
#  '../../data/Soaps/200350.jpg',
#  '../../data/Soaps/200352.jpg',
#  '../../data/Soaps/200186.jpg',
#  '../../data/Soaps/200221.jpg',
#  '../../data/Soaps/200177.jpg',
#  '../../data/Soaps/200273.jpg',
#  '../../data/Soaps/200016.jpg',
#  '../../data/Soaps/200414.jpg',
#  '../../data/Soaps/200372.jpg',
#  '../../data/Soaps/200038.jpg',
#  '../../data/IceCreams/120175.jpg',
#  '../../data/IceCreams/120476.jpg',
#  '../../data/Beverages/600380.jpg',
#  '../../data/Beverages/600011.jpg',
#  '../../data/Beverages/600290.jpg',
#  '../../data/Beverages/600200.jpg',
#  '../../data/Beverages/600188.jpg',
#  '../../data/Beverages/600426.jpg',
#  '../../data/Beverages/600050.jpg',
#  '../../data/Beverages/600398.jpg',
#  '../../data/Beverages/600056.jpg',
#  '../../data/Beverages/600096.jpg',
#  '../../data/Beverages/600030.jpg',
#  '../../data/Beverages/600297.jpg',
#  '../../data/HairCare/300410.jpg',
#  '../../data/HairCare/300093.jpg',
#  '../../data/HairCare/300186.jpg',
#  '../../data/HairCare/300207.jpg',
#  '../../data/HairCare/300068.jpg',
#  '../../data/HairCare/300146.jpg',
#  '../../data/HairCare/300169.jpg',
#  '../../data/HairCare/300493.jpg',
#  '../../data/HairCare/300039.jpg',
#  '../../data/HairCare/300051.jpg',
#  '../../data/HairCare/300086.jpg',
#  '../../data/HairCare/300134.jpg',
#  '../../data/Snacks/700020.jpg',
#  '../../data/Snacks/700197.jpg',
#  '../../data/Snacks/700034.jpg',
#  '../../data/Biscuits/400430.jpg',
#  '../../data/SoftDrinks/500438.jpg',
#  '../../data/SoftDrinks/500190.jpg',
#  '../../data/SoftDrinks/500074.jpg',
#  '../../data/SoftDrinks/500060.jpg',
#  '../../data/SoftDrinks/500011.jpg',
#  '../../data/SoftDrinks/500025.jpg',
#  '../../data/SoftDrinks/500399.jpg',
#  '../../data/SoftDrinks/500292.jpg',
#  '../../data/SoftDrinks/500132.jpg',
#  '../../data/SoftDrinks/500124.jpg',
#  '../../data/SoftDrinks/500461.jpg',
#  '../../data/SoftDrinks/500464.jpg',
#  '../../data/DentalCare/200019.jpg',
#  '../../data/DentalCare/100119.jpg',
#  '../../data/DentalCare/100147.jpg',
#  '../../data/DentalCare/100056.jpg',
#  '../../data/DentalCare/100024.jpg',
#  '../../data/DentalCare/100132.jpg',
#  '../../data/DentalCare/100163.jpg',
#  '../../data/DentalCare/100148.jpg',
#  '../../data/DentalCare/100027.jpg',
#  '../../data/DentalCare/100175.jpg',
#  '../../data/DentalCare/100034.jpg',
#  '../../data/DentalCare/100013.jpg',
#  '../../data/Soaps/200094.jpg',
#  '../../data/Soaps/200173.jpg',
#  '../../data/Soaps/200437.jpg',
#  '../../data/Soaps/200042.jpg',
#  '../../data/Soaps/200060.jpg',
#  '../../data/Soaps/200386.jpg',
#  '../../data/Soaps/200300.jpg',
#  ...]

# %%
win_path
# Out:
# '../../data/Snacks/700221.jpg'
